# %% [markdown]
# <a href="https://colab.research.google.com/github/jaspresso/WordCloud/blob/master/02_%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EC%8B%A4%EC%8A%B5_Seasonality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# [데이터타입 통합]
# [실습문제] kopo_channel_seasonality_new.csv 파일을 불러온 후 selloutData 변수에 담으세요. 이후 QTY컬럼->실수(float), 이외컬럼->문자(str)로 변경하세요.

# %%
# !pip show mysql-connector-python
# Out:
# WARNING: Package(s) not found: mysql-connector-python

# %%
import pandas as pd

# %%
from google.colab import drive

# %%
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Colab Notebooks/analysis_edu/05. 데이터분석 및 데이터 전처리
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/analysis_edu/05. 데이터분석 및 데이터 전처리

# %%
# 구글드라이브 용
googleUrl = "../dataset/kopo_channel_seasonality_new.csv"

# %%
selloutData = pd.read_csv(googleUrl)
selloutData
# Out:
#        REGIONID    PRODUCT  YEARWEEK      QTY
# 0           A60   PRODUCT4    201402     71.0
# 1           A60  PRODUCT59    201402  22275.0
# 2           A60  PRODUCT34    201402   4463.0
# 3           A60  PRODUCT47    201402      0.0
# 4           A60  PRODUCT56    201402     23.0
# ...         ...        ...       ...      ...
# 124653      A10  PRODUCT60    201630    824.0
# 124654      A10  PRODUCT56    201630    275.0
# 124655      A10  PRODUCT61    201630      0.0
# 124656      A10  PRODUCT12    201630  15021.0
# 124657      A10   PRODUCT1    201630    568.0
#
# [124658 rows x 4 columns]

# %%
selloutData = pd.read_csv("../dataset/kopo_channel_seasonality_new.csv")

colList = list(selloutData.columns)

for i in range(0, len(colList)):
  selloutData[colList[i]] = selloutData[colList[i]].astype(str)

selloutData.QTY = selloutData.QTY.astype(float)

# %%
selloutData
# Out:
#        REGIONID    PRODUCT YEARWEEK      QTY
# 0           A60   PRODUCT4   201402     71.0
# 1           A60  PRODUCT59   201402  22275.0
# 2           A60  PRODUCT34   201402   4463.0
# 3           A60  PRODUCT47   201402      0.0
# 4           A60  PRODUCT56   201402     23.0
# ...         ...        ...      ...      ...
# 124653      A10  PRODUCT60   201630    824.0
# 124654      A10  PRODUCT56   201630    275.0
# 124655      A10  PRODUCT61   201630      0.0
# 124656      A10  PRODUCT12   201630  15021.0
# 124657      A10   PRODUCT1   201630    568.0
#
# [124658 rows x 4 columns]

# %%
selloutData.dtypes
# Out:
# REGIONID     object
# PRODUCT      object
# YEARWEEK     object
# QTY         float64
# dtype: object

# %%
selloutData = pd.read_csv(googleUrl)
selloutData["QTY"] = selloutData["QTY"].astype(float)
selloutData["REGIONID"] = selloutData["REGIONID"].astype(str)
selloutData["PRODUCT"] = selloutData["PRODUCT"].astype(str)
selloutData["YEARWEEK"] = selloutData["YEARWEEK"].astype(str)

# %%
selloutData.dtypes
# Out:
# REGIONID     object
# PRODUCT      object
# YEARWEEK     object
# QTY         float64
# dtype: object

# %%
import pandas as pd

# 데이터 읽어오기
selloutData = pd.read_csv(googleUrl)

# 변환할 컬럼과 타입을 딕셔너리로 정의
column_types = {
    "QTY": float,
    "REGIONID": str,
    "PRODUCT": str,
    "YEARWEEK": str
}

# for문을 활용하여 타입 변환
for column, dtype in column_types.items():
    selloutData[column] = selloutData[column].astype(dtype)
selloutData
# Out:
#        REGIONID    PRODUCT YEARWEEK      QTY
# 0           A60   PRODUCT4   201402     71.0
# 1           A60  PRODUCT59   201402  22275.0
# 2           A60  PRODUCT34   201402   4463.0
# 3           A60  PRODUCT47   201402      0.0
# 4           A60  PRODUCT56   201402     23.0
# ...         ...        ...      ...      ...
# 124653      A10  PRODUCT60   201630    824.0
# 124654      A10  PRODUCT56   201630    275.0
# 124655      A10  PRODUCT61   201630      0.0
# 124656      A10  PRODUCT12   201630  15021.0
# 124657      A10   PRODUCT1   201630    568.0
#
# [124658 rows x 4 columns]

# %%
# [불량 데이터 처리]
# kopo_channel_seasonality_new.csv 자료를 담은 selloutData 변수에서
# QTY컬럼 음수(반품)인 경우 0, 양수인 경우 기존 QTY값 유지하는 로직을 적용하여 QTY_NEW 컬럼을 추가하세요.

# %%
import numpy as np

# %%
# QTY 음수 제거
selloutData["QTY_NEW"] = np.where( selloutData.QTY < 0, 0, selloutData.QTY)
selloutData.loc[ (selloutData.QTY < 0) &
                 (selloutData.QTY_NEW != 0)]
selloutData.loc[ (selloutData.QTY >= 0) &
                 (selloutData.QTY_NEW != selloutData.QTY)]
# Out:
# Empty DataFrame
# Columns: [REGIONID, PRODUCT, YEARWEEK, QTY, QTY_NEW]
# Index: []

# %%
# 연주차 컬럼 생성 및 특정 조회조건에 따른 데이터 제거
selloutData["YEAR"] = selloutData.YEARWEEK.str[:4]
selloutData["WEEK"] = selloutData.YEARWEEK.str[4:]
refinedSelloutData = selloutData.loc[ selloutData.WEEK.astype(int) <= 52 ]
refinedSelloutData.loc[ refinedSelloutData.WEEK == "53"]
selloutData.loc[ selloutData.WEEK == "53"].shape
selloutData.shape[0] - refinedSelloutData.shape[0]
# 123864
refinedSelloutData.shape
# Out:
# (123864, 7)
